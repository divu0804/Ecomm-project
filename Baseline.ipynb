# %% [markdown]
# BASELINE

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import datetime

import warnings
warnings.filterwarnings('ignore')

# %%
books = pd.read_csv('/content/books.csv.zip')
ratings = pd.read_csv('/content/ratings.csv.zip')
book_tags = pd.read_csv('/content/book_tags.csv.zip')
tags = pd.read_csv('/content/tags.csv')

# %%
books['original_publication_year'] = books['original_publication_year'].fillna(-1).apply(lambda x: int(x) if x != -1 else -1)

# %%
ratings_rmv_duplicates = ratings.drop_duplicates()
unwanted_users = ratings_rmv_duplicates.groupby('user_id')['user_id'].count()
unwanted_users = unwanted_users[unwanted_users < 3]
unwanted_ratings = ratings_rmv_duplicates[ratings_rmv_duplicates.user_id.isin(unwanted_users.index)]
new_ratings = ratings_rmv_duplicates.drop(unwanted_ratings.index)

# %%
new_ratings['title'] = books.set_index('id').title.loc[new_ratings.book_id].values

# %%
new_ratings.head(10)
# Out:
#    book_id  user_id  rating                                    title
# 0        1      314       5  The Hunger Games (The Hunger Games, #1)
# 1        1      439       3  The Hunger Games (The Hunger Games, #1)
# 2        1      588       5  The Hunger Games (The Hunger Games, #1)
# 3        1     1169       4  The Hunger Games (The Hunger Games, #1)
# 4        1     1185       4  The Hunger Games (The Hunger Games, #1)
# 5        1     2077       4  The Hunger Games (The Hunger Games, #1)
# 6        1     2487       4  The Hunger Games (The Hunger Games, #1)
# 7        1     2900       5  The Hunger Games (The Hunger Games, #1)
# 8        1     3662       4  The Hunger Games (The Hunger Games, #1)
# 9        1     3922       5  The Hunger Games (The Hunger Games, #1)

# %% [markdown]
# The Baseline Recommender provides generalized recommendations based on book popularity and sometimes genre. It prioritizes books that are both popular and critically acclaimed, assuming they're more likely to be enjoyed by the average audience.

# %%
v = books['ratings_count']
m = books['ratings_count'].quantile(0.95)
R = books['average_rating']
C = books['average_rating'].mean()
W = (R*v + C*m) / (v + m)

# %%
books['weighted_rating'] = W
qualified  = books.sort_values('weighted_rating', ascending=False).head(250)

# %%
#Top Books
qualified[['title', 'authors', 'average_rating', 'weighted_rating']].head(15)
# Out:
#                                                  title  \
# 24   Harry Potter and the Deathly Hallows (Harry Po...
# 26   Harry Potter and the Half-Blood Prince (Harry ...
# 17   Harry Potter and the Prisoner of Azkaban (Harr...
# 23   Harry Potter and the Goblet of Fire (Harry Pot...
# 1    Harry Potter and the Sorcerer's Stone (Harry P...
# 20   Harry Potter and the Order of the Phoenix (Har...
# 30                                            The Help
# 38      A Game of Thrones (A Song of Ice and Fire, #1)
# 134     A Storm of Swords (A Song of Ice and Fire, #3)
# 421           Harry Potter Boxset (Harry Potter, #1-7)
# 191  The Name of the Wind (The Kingkiller Chronicle...
# 160  The Return of the King (The Lord of the Rings,...
# 174  The Last Olympian (Percy Jackson and the Olymp...
# 22   Harry Potter and the Chamber of Secrets (Harry...
# 306  The Wise Man's Fear (The Kingkiller Chronicle,...
#
#                                      authors  average_rating  weighted_rating
# 24               J.K. Rowling, Mary GrandPré            4.61         4.555956
# 26               J.K. Rowling, Mary GrandPré            4.54         4.490428
# 17   J.K. Rowling, Mary GrandPré, Rufus Beck            4.53         4.485090
# 23               J.K. Rowling, Mary GrandPré            4.53         4.483227
# 1                J.K. Rowling, Mary GrandPré            4.44         4.424365
# 20               J.K. Rowling, Mary GrandPré            4.46         4.419054
# 30                          Kathryn Stockett            4.45         4.405158
# 38                        George R.R. Martin            4.45         4.398759
# 134                       George R.R. Martin            4.54         4.396645
# 421                             J.K. Rowling            4.74         4.391147
# 191                         Patrick Rothfuss            4.55         4.386341
# 160                           J.R.R. Tolkien            4.51         4.373561
# 174                             Rick Riordan            4.50         4.350597
# 22               J.K. Rowling, Mary GrandPré            4.37         4.337845
# 306                         Patrick Rothfuss            4.57         4.337421

# %%
#Top Genres of Books
book_tags.head()
# Out:
#    goodreads_book_id  tag_id   count
# 0                  1   30574  167697
# 1                  1   11305   37174
# 2                  1   11557   34173
# 3                  1    8717   12986
# 4                  1   33114   12716

# %%
tags.head()
# Out:
#    tag_id tag_name
# 0       0        -
# 1       1     --1-
# 2       2    --10-
# 3       3    --12-
# 4       4   --122-

# %%
genres = ["Art", "Biography", "Business", "Chick Lit", "Children's", "Christian", "Classics",
          "Comics", "Contemporary", "Cookbooks", "Crime", "Ebooks", "Fantasy", "Fiction",
          "Gay and Lesbian", "Graphic Novels", "Historical Fiction", "History", "Horror",
          "Humor and Comedy", "Manga", "Memoir", "Music", "Mystery", "Nonfiction", "Paranormal",
          "Philosophy", "Poetry", "Psychology", "Religion", "Romance", "Science", "Science Fiction",
          "Self Help", "Suspense", "Spirituality", "Sports", "Thriller", "Travel", "Young Adult"]

# %%
genres = list(map(str.lower, genres))
genres[:4]
# Out:
# ['art', 'biography', 'business', 'chick lit']

# %%
available_genres = tags.loc[tags.tag_name.str.lower().isin(genres)]
available_genres.head()
# Out:
#       tag_id   tag_name
# 2938    2938        art
# 4605    4605  biography
# 5951    5951   business
# 7077    7077  christian
# 7457    7457   classics

# %%
available_genres_books = book_tags[book_tags.tag_id.isin(available_genres.tag_id)]
print('There are {} books that are tagged with above genres'.format(available_genres_books.shape[0]))
# Out:
# There are 60573 books that are tagged with above genres

# %%
available_genres_books['genre'] = available_genres.tag_name.loc[available_genres_books.tag_id].values
available_genres_books.head()
# Out:
#     goodreads_book_id  tag_id  count       genre
# 1                   1   11305  37174     fantasy
# 5                   1   11743   9954     fiction
# 25                  1    7457    958    classics
# 38                  1   22973    673  paranormal
# 52                  1   20939    465     mystery

# %%
def build_chart(genre, percentile=0.85):
    df = available_genres_books[available_genres_books['genre'] == genre.lower()]
    qualified = books.set_index('book_id').loc[df.goodreads_book_id]

    v = qualified['ratings_count']
    m = qualified['ratings_count'].quantile(percentile)
    R = qualified['average_rating']
    C = qualified['average_rating'].mean()
    qualified['weighted_rating'] = (R*v + C*m) / (v + m)

    qualified.sort_values('weighted_rating', ascending=False, inplace=True)
    return qualified

# %%
cols = ['title','authors','original_publication_year','average_rating','ratings_count','work_text_reviews_count','weighted_rating']

# %%
genre = 'Fiction'
build_chart(genre)[cols].head(15)
# Out:
#                                                       title  \
# book_id
# 136251    Harry Potter and the Deathly Hallows (Harry Po...
# 862041             Harry Potter Boxset (Harry Potter, #1-7)
# 1         Harry Potter and the Half-Blood Prince (Harry ...
# 5         Harry Potter and the Prisoner of Azkaban (Harr...
# 6         Harry Potter and the Goblet of Fire (Harry Pot...
# 62291        A Storm of Swords (A Song of Ice and Fire, #3)
# 186074    The Name of the Wind (The Kingkiller Chronicle...
# 1215032   The Wise Man's Fear (The Kingkiller Chronicle,...
# 18512     The Return of the King (The Lord of the Rings,...
# 2         Harry Potter and the Order of the Phoenix (Har...
# 17927395  A Court of Mist and Fury (A Court of Thorns an...
# 7235533       The Way of Kings (The Stormlight Archive, #1)
# 3         Harry Potter and the Sorcerer's Stone (Harry P...
# 4667024                                            The Help
# 13496        A Game of Thrones (A Song of Ice and Fire, #1)
#
#                                           authors  original_publication_year  \
# book_id
# 136251                J.K. Rowling, Mary GrandPré                       2007
# 862041                               J.K. Rowling                       1998
# 1                     J.K. Rowling, Mary GrandPré                       2005
# 5         J.K. Rowling, Mary GrandPré, Rufus Beck                       1999
# 6                     J.K. Rowling, Mary GrandPré                       2000
# 62291                          George R.R. Martin                       2000
# 186074                           Patrick Rothfuss                       2007
# 1215032                          Patrick Rothfuss                       2011
# 18512                              J.R.R. Tolkien                       1955
# 2                     J.K. Rowling, Mary GrandPré                       2003
# 17927395                            Sarah J. Maas                       2016
# 7235533                         Brandon Sanderson                       2010
# 3                     J.K. Rowling, Mary GrandPré                       1997
# 4667024                          Kathryn Stockett                       2009
# 13496                          George R.R. Martin                       1996
#
#           average_rating  ratings_count  work_text_reviews_count  \
# book_id
# 136251              4.61        1746574                    51942
# 862041              4.74         190050                     6508
# 1                   4.54        1678823                    27520
# 5                   4.53        1832823                    36099
# 6                   4.53        1753043                    31084
# 62291               4.54         469022                    19497
# 186074              4.55         400101                    28631
# 1215032             4.57         245686                    15503
# 18512               4.51         463959                     6644
# 2                   4.46        1735368                    28685
# 17927395            4.72         108384                    22700
# 7235533             4.64         144822                    10947
# 3                   4.44        4602479                    75867
# 4667024             4.45        1531753                    78204
# 13496               4.45        1319204                    46205
#
#           weighted_rating
# book_id
# 136251           4.587098
# 862041           4.544691
# 1                4.518933
# 5                4.510997
# 6                4.510164
# 62291            4.471466
# 186074           4.469922
# 1215032          4.446163
# 18512            4.444645
# 2                4.442607
# 17927395         4.441935
# 7235533          4.435102
# 3                4.433575
# 4667024          4.430818
# 13496            4.427878

# %%
list(enumerate(available_genres.tag_name))
# Out:
# [(0, 'art'),
#  (1, 'biography'),
#  (2, 'business'),
#  (3, 'christian'),
#  (4, 'classics'),
#  (5, 'comics'),
#  (6, 'contemporary'),
#  (7, 'cookbooks'),
#  (8, 'crime'),
#  (9, 'ebooks'),
#  (10, 'fantasy'),
#  (11, 'fiction'),
#  (12, 'history'),
#  (13, 'horror'),
#  (14, 'manga'),
#  (15, 'memoir'),
#  (16, 'music'),
#  (17, 'mystery'),
#  (18, 'nonfiction'),
#  (19, 'paranormal'),
#  (20, 'philosophy'),
#  (21, 'poetry'),
#  (22, 'psychology'),
#  (23, 'religion'),
#  (24, 'romance'),
#  (25, 'science'),
#  (26, 'spirituality'),
#  (27, 'sports'),
#  (28, 'suspense'),
#  (29, 'thriller'),
#  (30, 'travel')]

# %%
idx = 12  #history
build_chart(list(available_genres.tag_name)[idx])[cols].head(15)
# Out:
#                                                       title  \
# book_id
# 4667024                                            The Help
# 21853621                                    The Nightingale
# 8664353   Unbroken: A World War II Story of Survival, Re...
# 19063                                        The Book Thief
# 11422                                        Redeeming Love
# 128029                             A Thousand Splendid Suns
# 1923820                      Holy Bible: King James Version
# 561909    The Hiding Place: The Triumphant True Story of...
# 256008                                        Lonesome Dove
# 4406                                           East of Eden
# 15195                        The Complete Maus (Maus, #1-2)
# 1617                           Night (The Night Trilogy #1)
# 95617            A Voice in the Wind (Mark of the Lion, #1)
# 18143977                        All the Light We Cannot See
# 546018                Roots: The Saga of an American Family
#
#                                                     authors  \
# book_id
# 4667024                                    Kathryn Stockett
# 21853621                                     Kristin Hannah
# 8664353                                   Laura Hillenbrand
# 19063                                          Markus Zusak
# 11422                                       Francine Rivers
# 128029                                      Khaled Hosseini
# 1923820                                           Anonymous
# 561909    Corrie ten Boom, John Sherrill, Elizabeth Sher...
# 256008                                       Larry McMurtry
# 4406                                         John Steinbeck
# 15195                                        Art Spiegelman
# 1617                             Elie Wiesel, Marion Wiesel
# 95617                      Francine Rivers, Richard Ferrone
# 18143977                                      Anthony Doerr
# 546018                                           Alex Haley
#
#           original_publication_year  average_rating  ratings_count  \
# book_id
# 4667024                        2009            4.45        1531753
# 21853621                       2015            4.54         253606
# 8664353                        2010            4.40         487775
# 19063                          2005            4.36        1159741
# 11422                          1991            4.48         157506
# 128029                         2007            4.34         818742
# 1923820                        1611            4.43         159457
# 561909                         1971            4.42         171384
# 256008                         1985            4.47         111498
# 4406                           1952            4.35         320919
# 15195                          1986            4.53          76785
# 1617                           1958            4.30         691231
# 95617                          1993            4.60          55556
# 18143977                       2014            4.31         470001
# 546018                         1976            4.42         118951
#
#           work_text_reviews_count  weighted_rating
# book_id
# 4667024                     78204         4.431319
# 21853621                    37279         4.428014
# 8664353                     41572         4.351917
# 19063                       93611         4.340421
# 11422                        9147         4.337177
# 128029                      43645         4.314338
# 1923820                      4438         4.302898
# 561909                       7801         4.302061
# 256008                       5343         4.293630
# 4406                        14454         4.289550
# 15195                        4733         4.282944
# 1617                        22001         4.273449
# 95617                        2647         4.271698
# 18143977                    53413         4.271255
# 546018                       2644         4.268444
